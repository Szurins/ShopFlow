# %% [markdown]
# # Initializing schemas and catalog

# %%
# %sql
CREATE CATALOG IF NOT EXISTS `shopflow`;
CREATE SCHEMA IF NOT EXISTS `shopflow`.bronze;
CREATE SCHEMA IF NOT EXISTS `shopflow`.dbt_schema;
CREATE SCHEMA IF NOT EXISTS `shopflow`.gold;
