# %% [markdown]
# # Loading in data

# %% [markdown]
# ## Customers data

# %%
df = spark.read.csv("s3://brazilian-e-commerce-data-331721825218-eu-north-1-an/olist_customers_dataset.csv", inferSchema=True, header=True)
df.write.mode("overwrite").saveAsTable("shopflow.bronze.bronze_customers")

# %% [markdown]
# ## Geolocation data

# %%
df = spark.read.csv("s3://brazilian-e-commerce-data-331721825218-eu-north-1-an/olist_geolocation_dataset.csv", inferSchema=True, header=True)
df.write.mode("overwrite").saveAsTable("shopflow.bronze.bronze_geolocation")

# %% [markdown]
# ## Order items data

# %%
df = spark.read.csv("s3://brazilian-e-commerce-data-331721825218-eu-north-1-an/olist_order_items_dataset.csv", inferSchema=True, header=True)
df.write.mode("overwrite").saveAsTable("shopflow.bronze.bronze_order_items")

# %% [markdown]
# ## Order payment data

# %%
df = spark.read.csv("s3://brazilian-e-commerce-data-331721825218-eu-north-1-an/olist_order_payments_dataset.csv", inferSchema=True, header=True)
df.write.mode("overwrite").saveAsTable("shopflow.bronze.bronze_order_payments")

# %% [markdown]
# ## Order reviews data

# %%
df = spark.read.csv("s3://brazilian-e-commerce-data-331721825218-eu-north-1-an/olist_order_reviews_dataset.csv", inferSchema=True, header=True)
df.write.mode("overwrite").saveAsTable("shopflow.bronze.bronze_order_reviews")

# %% [markdown]
# ## Orders data

# %%
df = spark.read.csv("s3://brazilian-e-commerce-data-331721825218-eu-north-1-an/olist_orders_dataset.csv", inferSchema=True, header=True)
df.write.mode("overwrite").saveAsTable("shopflow.bronze.bronze_orders")

# %% [markdown]
# ## Products data

# %%
df = spark.read.csv("s3://brazilian-e-commerce-data-331721825218-eu-north-1-an/olist_products_dataset.csv", inferSchema=True, header=True)
df.write.mode("overwrite").saveAsTable("shopflow.bronze.bronze_products")

# %% [markdown]
# ## Sellers data

# %%
df = spark.read.csv("s3://brazilian-e-commerce-data-331721825218-eu-north-1-an/olist_sellers_dataset.csv", inferSchema=True, header=True)
df.write.mode("overwrite").saveAsTable("shopflow.bronze.bronze_sellers")

# %% [markdown]
# ## Product category translation data

# %%
df = spark.read.csv("s3://brazilian-e-commerce-data-331721825218-eu-north-1-an/product_category_name_translation.csv", inferSchema=True, header=True)
df.write.mode("overwrite").saveAsTable("shopflow.bronze.bronze_product_translation")
